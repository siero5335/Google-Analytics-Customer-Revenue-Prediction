# %%
import pandas as pd 
from pandas.io.json import json_normalize
from ast import literal_eval

# %%
MAXROWS = 1e5 # per chunk

# %%
train_base = pd.read_csv('data/train_v2.csv', usecols=['fullVisitorId','visitStartTime'], skiprows=0, low_memory=False)
test_base = pd.read_csv('data/test_v2.csv', usecols=['fullVisitorId','visitStartTime'], skiprows=0, low_memory=False)

# %%
train_base.head()
# Out:
#          fullVisitorId  visitStartTime
# 0  3162355547410993243      1508198450
# 1  8934116514970143966      1508176307
# 2  7992466427990357681      1508201613
# 3  9075655783635761930      1508169851
# 4  6960673291025684308      1508190552

# %%
base_df = pd.concat([train_base, test_base], ignore_index = True, copy = False, join = "outer", sort = True)

# %%
df_list = []
for file in ['data/train_v2.csv', 'data/test_v2.csv']:
    reader = pd.read_csv(file, usecols=[6], chunksize = MAXROWS, skiprows=0, low_memory=False)
    for chunk in reader:
        chunk.columns = ['hits']
        chunk['hits'][chunk['hits'] == "[]"] = "[{}]"
        chunk['hits'] = chunk['hits'].apply(literal_eval).str[0]
        chunk = json_normalize(chunk['hits'])

        # Extract the product and promo names from the complex nested structure into a simple flat list:
        if 'product' in chunk.columns:
            #print(chunk['product'][0])
            chunk['v2ProductName'] = chunk['product'].apply(lambda x: [p['v2ProductName'] for p in x] if type(x) == list else [])
            chunk['v2ProductCategory'] = chunk['product'].apply(lambda x: [p['v2ProductCategory'] for p in x] if type(x) == list else [])
            del chunk['product']
        if 'promotion' in chunk.columns:
            #print(chunk['promotion'][0])
            chunk['promoId']  = chunk['promotion'].apply(lambda x: [p['promoId'] for p in x] if type(x) == list else [])
            chunk['promoName']  = chunk['promotion'].apply(lambda x: [p['promoName'] for p in x] if type(x) == list else [])
            del chunk['promotion']

        df_list.append(chunk)
        print(f"Chunk {len(df_list)} completed: {len(chunk)} rows from '{file}'")
# Out:
# Chunk 1 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 2 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 3 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 4 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 5 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 6 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 7 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 8 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 9 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 10 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 11 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 12 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 13 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 14 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 15 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 16 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 17 completed: 100000 rows from 'data/train_v2.csv'
# Chunk 18 completed: 8337 rows from 'data/train_v2.csv'
# Chunk 19 completed: 100000 rows from 'data/test_v2.csv'
# Chunk 20 completed: 100000 rows from 'data/test_v2.csv'
# Chunk 21 completed: 100000 rows from 'data/test_v2.csv'
# Chunk 22 completed: 100000 rows from 'data/test_v2.csv'
# Chunk 23 completed: 1589 rows from 'data/test_v2.csv'

# %%
df = pd.concat(df_list, ignore_index = True, copy = False, join = "outer", sort = True)

# %%
df.shape
# Out:
# (2109926, 79)

# %%
df.head()
# Out:
#                               appInfo.exitScreenName  \
# 0  shop.googlemerchandisestore.com/google+redesig...
# 1       shop.googlemerchandisestore.com/asearch.html
# 2  shop.googlemerchandisestore.com/google+redesig...
# 3  shop.googlemerchandisestore.com/google+redesig...
# 4  shop.googlemerchandisestore.com/google+redesig...
#
#                            appInfo.landingScreenName appInfo.screenDepth  \
# 0  shop.googlemerchandisestore.com/google+redesig...                   0
# 1               shop.googlemerchandisestore.com/home                   0
# 2               shop.googlemerchandisestore.com/home                   0
# 3               shop.googlemerchandisestore.com/home                   0
# 4               shop.googlemerchandisestore.com/home                   0
#
#                                   appInfo.screenName  \
# 0  shop.googlemerchandisestore.com/google+redesig...
# 1               shop.googlemerchandisestore.com/home
# 2               shop.googlemerchandisestore.com/home
# 3               shop.googlemerchandisestore.com/home
# 4               shop.googlemerchandisestore.com/home
#
#   contentGroup.contentGroup1 contentGroup.contentGroup2  \
# 0                  (not set)                       Bags
# 1                  (not set)                  (not set)
# 2                  (not set)                  (not set)
# 3                  (not set)                  (not set)
# 4                  (not set)                  (not set)
#
#   contentGroup.contentGroup3 contentGroup.contentGroup4  \
# 0                  (not set)                  (not set)
# 1                  (not set)                  (not set)
# 2                  (not set)                  (not set)
# 3                  (not set)                  (not set)
# 4                  (not set)                  (not set)
#
#   contentGroup.contentGroup5 contentGroup.contentGroupUniqueViews1  \
# 0                  (not set)                                   NaN
# 1                  (not set)                                   NaN
# 2                  (not set)                                   NaN
# 3                  (not set)                                   NaN
# 4                  (not set)                                   NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   transaction.localTransactionRevenue transaction.localTransactionShipping  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   transaction.localTransactionTax transaction.transactionId  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#   transaction.transactionRevenue transaction.transactionShipping  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   transaction.transactionTax  type  \
# 0                        NaN  PAGE
# 1                        NaN  PAGE
# 2                        NaN  PAGE
# 3                        NaN  PAGE
# 4                        NaN  PAGE
#
#                                    v2ProductCategory  \
# 0  [Home/Drinkware/Water Bottles and Tumblers/, H...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                        v2ProductName
# 0  [Google 17oz Stainless Steel Sport Bottle, 26 ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
# [5 rows x 79 columns]

# %%
dff = pd.concat([train_base, df], axis=1)

# %%
dff.to_csv('data/concat_hit.csv')

# %%
dff.shape
# Out:
# (2109926, 81)

# %%
dff.head()
# Out:
#          fullVisitorId  visitStartTime  \
# 0  3162355547410993243    1.508198e+09
# 1  8934116514970143966    1.508176e+09
# 2  7992466427990357681    1.508202e+09
# 3  9075655783635761930    1.508170e+09
# 4  6960673291025684308    1.508191e+09
#
#                               appInfo.exitScreenName  \
# 0  shop.googlemerchandisestore.com/google+redesig...
# 1       shop.googlemerchandisestore.com/asearch.html
# 2  shop.googlemerchandisestore.com/google+redesig...
# 3  shop.googlemerchandisestore.com/google+redesig...
# 4  shop.googlemerchandisestore.com/google+redesig...
#
#                            appInfo.landingScreenName appInfo.screenDepth  \
# 0  shop.googlemerchandisestore.com/google+redesig...                   0
# 1               shop.googlemerchandisestore.com/home                   0
# 2               shop.googlemerchandisestore.com/home                   0
# 3               shop.googlemerchandisestore.com/home                   0
# 4               shop.googlemerchandisestore.com/home                   0
#
#                                   appInfo.screenName  \
# 0  shop.googlemerchandisestore.com/google+redesig...
# 1               shop.googlemerchandisestore.com/home
# 2               shop.googlemerchandisestore.com/home
# 3               shop.googlemerchandisestore.com/home
# 4               shop.googlemerchandisestore.com/home
#
#   contentGroup.contentGroup1 contentGroup.contentGroup2  \
# 0                  (not set)                       Bags
# 1                  (not set)                  (not set)
# 2                  (not set)                  (not set)
# 3                  (not set)                  (not set)
# 4                  (not set)                  (not set)
#
#   contentGroup.contentGroup3 contentGroup.contentGroup4  \
# 0                  (not set)                  (not set)
# 1                  (not set)                  (not set)
# 2                  (not set)                  (not set)
# 3                  (not set)                  (not set)
# 4                  (not set)                  (not set)
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   transaction.localTransactionRevenue transaction.localTransactionShipping  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   transaction.localTransactionTax transaction.transactionId  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#   transaction.transactionRevenue transaction.transactionShipping  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   transaction.transactionTax  type  \
# 0                        NaN  PAGE
# 1                        NaN  PAGE
# 2                        NaN  PAGE
# 3                        NaN  PAGE
# 4                        NaN  PAGE
#
#                                    v2ProductCategory  \
# 0  [Home/Drinkware/Water Bottles and Tumblers/, H...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                        v2ProductName
# 0  [Google 17oz Stainless Steel Sport Bottle, 26 ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
# [5 rows x 81 columns]
